# %% [markdown]
# ## Importing relevant packages and modules
# Namely:
# * numpy
# * pandas
# * seaborn
# * matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Getting the dataset
# Sklearn has some datasets helpers to fetch larger datasets commonly used by the machine learning community to benchmark algorithms on data that comes from the 'real world'.
# We will make use of the Boston housing dataset from sklearn
# This dataset is read as a dataframe

# %%
# Importing the boston housing dataset
from sklearn.datasets import load_boston
boston = load_boston()

# %% [markdown]
# # Data exploration and cleaning
# * We will proceed to get some information from the dataset
# * DESCR - Gives detailed information about the dataset
# * feature_names gives Informations about the column names

# %%
print(boston.DESCR)
##DESCR - Gives detailed information about the dataset
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
boston.feature_names
##feature_names gives Informations about the column names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %% [markdown]
# ## Converting data into a pandas dataframe

# %%
df = pd.DataFrame(boston.data, columns=boston.feature_names)

# %% [markdown]
# #### We can take a closer look at the data with the  help of “head()”function of pandas library which returns first five observations.

# %%
# take a look at the dataset
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# ## The prices of houses is missing from the dataset
# * This is crucial information in this dataset.
# * We will add house prices to the dataset.
# * We can take a closer look at the data again with the help of “head()”function of pandas library which returns first five observations

# %%
df['MEDV'] = boston.target

# %%
df.head() # take a look at the dataset now
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.info() #get a concise summary of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %% [markdown]
# ### After you have looked at the dataset, you might want to know a little bit more about it.
# * You can check attributes names and datatypes using info().
# * We will also be to check is if there are null-values or different types of values in one column
# * This will also show:
#
# <ul>
#     <li>the count of that variable</li>
#     <li>the mean</li>
#     <li>the standard deviation (std)</li>
#     <li>the minimum value</li>
#     <li>the IQR (Interquartile Range: 25%, 50% and 75%)</li>
#     <li>the maximum value</li>
# <ul>

# %% [markdown]
#  We can apply the method "describe" as follows:

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ## Outcome
# * This dataset has 506 samples, and 14 attributes.
# * No variable column has null/missing values.
# * All column types are of type float.

# %% [markdown]
# <h2>Visualizations</h2>

# %%
#Plot pairwise relationships in a dataset
sns.pairplot(df)

# %%
##seaborn.distplot will allow you to easily fit a normal distribution to each histogram plot and make the visualization easier.

rows = 7
cols = 2

fig, ax = plt.subplots(nrows= rows, ncols= cols, figsize = (16,16))
col = df.columns
index = 0
for i in range(rows):
    for j in range(cols):
        sns.distplot(df[col[index]], ax = ax[i][j])
        index = index + 1
        
plt.tight_layout()

# %% [markdown]
# #### Checking the correlations of and summarizing the relationships between the variables.
# * A correlation factor near 1 or -1 is wanted.
# * 0 means that there is no linearrelation between that columns and they will sabotage the linear regression model

# %%
fig, ax = plt.subplots(figsize = (16, 9))
sns.heatmap(df.corr(), annot = True, annot_kws={'size': 12})
# Out:
# <AxesSubplot:>

# %% [markdown]
# For a linear regression model, we need high correlations. in that case, we need to define a threshold filter

# %%
def getCorrelatedFeature(corrdata, threshold):
    feature = []
    value = []
    
    for i, index in enumerate(corrdata.index):
        if abs(corrdata[index])> threshold:
            feature.append(index)
            value.append(corrdata[index])
            
    df = pd.DataFrame(data = value, index = feature, columns=['Corr Value'])
    return df

# %%
threshold = 0.4
corr_value = getCorrelatedFeature(df.corr()['MEDV'], threshold)

# %%
corr_value.index.values
# Out:
# array(['INDUS', 'NOX', 'RM', 'TAX', 'PTRATIO', 'LSTAT', 'MEDV'],
#       dtype=object)

# %%
correlated_data = df[corr_value.index]
correlated_data.head()
# Out:
#    INDUS    NOX     RM    TAX  PTRATIO  LSTAT  MEDV
# 0   2.31  0.538  6.575  296.0     15.3   4.98  24.0
# 1   7.07  0.469  6.421  242.0     17.8   9.14  21.6
# 2   7.07  0.469  7.185  242.0     17.8   4.03  34.7
# 3   2.18  0.458  6.998  222.0     18.7   2.94  33.4
# 4   2.18  0.458  7.147  222.0     18.7   5.33  36.2

# %% [markdown]
# #### Creating train and test dataset
#
# Train/Test Split involves splitting the dataset into training and testing sets respectively, which are mutually exclusive. After which, you train with the training set and test with the testing set.
# This will provide a more accurate evaluation on out-of-sample accuracy because the testing dataset is not part of the dataset that have been used to train the data. It is more realistic for real world problems.
#
# This means that we know the outcome of each data point in this dataset, making it great to test with! And since this data has not been used to train the model, the model has no knowledge of the outcome of these data points. So, in essence, it’s truly an out-of-sample testing.

# %%
X = correlated_data.drop(labels=['MEDV'], axis = 1)
y = correlated_data['MEDV']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33,random_state=1)

# %% [markdown]
# <h2>Regression Model</h2>

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.distplot((y_test-predictions),bins=50)
# Out:
# <AxesSubplot:xlabel='MEDV'>

# %%
lm.intercept_
# Out:
# 23.49923705354543

# %%
lm.coef_
# Out:
# array([ 1.08016127e-01, -7.91996313e+00,  4.30011673e+00, -2.02636592e-04,
#        -9.66142294e-01, -5.36384366e-01])

# %% [markdown]
#  **Coefficient** and **Intercept** are the parameters of the fit line.
# Given that it is a multiple linear regression and knowing that the parameters are the intercept and coefficients of hyperplane, sklearn can estimate them from our data. Scikit-learn uses plain Ordinary Least Squares method to solve this problem.
#
# #### Ordinary Least Squares (OLS)
#
# OLS is a method for estimating the unknown parameters in a linear regression model. OLS chooses the parameters of a linear function of a set of explanatory variables by minimizing the sum of the squares of the differences between the target dependent variable and those predicted by the linear function. In other words, it tries to minimizes the sum of squared errors (SSE) or mean squared error (MSE) between the target variable (y) and our predicted output ($\\hat{y}$) over all samples in the dataset.
#
# OLS can find the best parameters using of the following methods:
#
# ```
# - Solving the model parameters analytically using closed-form equations
# - Using an optimization algorithm (Gradient Descent, Stochastic Gradient Descent, Newton’s Method)
# ```

# %%
##Defining the linear regression funcion

def lin_func(values, coefficients=lm.coef_, y_axis=lm.intercept_):
    return np.dot(values, coefficients) + y_axis

# %% [markdown]
# <h2>Samples</h2>

# %% [markdown]
# For that defining random test data and make some samples so we can see what we have created

# %%
from random import randint
for i in range(5):
    index = randint(0,len(df)-1)
    sample = df.iloc[index][corr_value.index.values].drop('MEDV')
    print(
        'PREDICTION: ', round(lin_func(sample),2),
        ' // REAL: ',df.iloc[index]['MEDV'],
        ' // DIFFERENCE: ', round(round(lin_func(sample),2) - df.iloc[index]['MEDV'],2)
    )
# Out:
# PREDICTION:  32.1  // REAL:  35.2  // DIFFERENCE:  -3.1
# PREDICTION:  39.65  // REAL:  50.0  // DIFFERENCE:  -10.35
# PREDICTION:  24.82  // REAL:  23.9  // DIFFERENCE:  0.92
# PREDICTION:  39.25  // REAL:  50.0  // DIFFERENCE:  -10.75
# PREDICTION:  23.93  // REAL:  20.7  // DIFFERENCE:  3.23
